# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
train_independent=sc.fit_transform(independent)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
           'max_features':[None,'sqrt','log2'],
           'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(train_independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print(re)
# Out:
# {'mean_fit_time': array([0.01647148, 0.00937562, 0.01250072, 0.00937514, 0.01562767,
#        0.00937567, 0.07813087, 0.06250467, 0.04863486, 0.03838201,
#        0.04062686, 0.04062738, 0.01563444, 0.01250157, 0.00937462,
#        0.01250129, 0.01562591, 0.00937781, 0.0156249 , 0.00937533,
#        0.00937676, 0.01250067, 0.01562638, 0.00937595]), 'std_fit_time': array([1.74456609e-03, 7.65516158e-03, 6.25035827e-03, 7.65477279e-03,
#        1.44159474e-06, 7.65520058e-03, 2.79509561e-06, 9.88159003e-03,
#        3.50768905e-03, 7.11641104e-03, 7.65237789e-03, 7.65309883e-03,
#        1.20495533e-05, 6.25078695e-03, 7.65434412e-03, 6.25064520e-03,
#        2.80240731e-06, 7.65695271e-03, 3.83728019e-06, 7.65492847e-03,
#        7.65609688e-03, 6.25033500e-03, 1.94512158e-06, 7.65543418e-03]), 'mean_score_time': array([0.0057188 , 0.00937614, 0.0031251 , 0.00625114, 0.00312595,
#        0.00312548, 0.        , 0.        , 0.        , 0.00087194,
#        0.003125  , 0.00312524, 0.00312519, 0.        , 0.00625243,
#        0.00312486, 0.        , 0.        , 0.00312619, 0.00312624,
#        0.00625234, 0.00312452, 0.        , 0.        ]), 'std_score_time': array([0.00614975, 0.00765559, 0.00625019, 0.00765606, 0.00625191,
#        0.00625095, 0.        , 0.        , 0.        , 0.00174389,
#        0.00625   , 0.00625048, 0.00625038, 0.        , 0.00765763,
#        0.00624971, 0.        , 0.        , 0.00625238, 0.00625248,
#        0.00765752, 0.00624905, 0.        , 0.        ]), 'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                    'squared_error', 'squared_error', 'squared_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                    'poisson'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_features': masked_array(data=[None, None, 'sqrt', 'sqrt', 'log2', 'log2', None, None,
#                    'sqrt', 'sqrt', 'log2', 'log2', None, None, 'sqrt',
#                    'sqrt', 'log2', 'log2', None, None, 'sqrt', 'sqrt',
#                    'log2', 'log2'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_splitter': masked_array(data=['best', 'random', 'best', 'random', 'best', 'random',
#                    'best', 'random', 'best', 'random', 'best', 'random',
#                    'best', 'random', 'best', 'random', 'best', 'random',
#                    'best', 'random', 'best', 'random', 'best', 'random'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'criterion': 'squared_error', 'max_features': None, 'splitter': 'best'}, {'criterion': 'squared_error', 'max_features': None, 'splitter': 'random'}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'}, {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'best'}, {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'random'}, {'criterion': 'friedman_mse', 'max_features': None, 'splitter': 'best'}, {'criterion': 'friedman_mse', 'max_features': None, 'splitter': 'random'}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'}, {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}, {'criterion': 'poisson', 'max_features': None, 'splitter': 'random'}, {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'random'}], 'split0_test_score': array([0.72760199, 0.65852612, 0.73473557, 0.70348622, 0.67117494,
#        0.72565363, 0.76210506, 0.65252959, 0.66711511, 0.66911021,
#        0.76448196, 0.57930179, 0.73185868, 0.72915927, 0.71888288,
#        0.64493539, 0.7386159 , 0.70838271, 0.75138336, 0.61366911,
#        0.72738352, 0.68552008, 0.72615881, 0.6847537 ]), 'split1_test_score': array([0.60270852, 0.6182453 , 0.5536403 , 0.5820827 , 0.64005606,
#        0.44365076, 0.58599958, 0.55847027, 0.55125978, 0.50448678,
#        0.6378285 , 0.62117958, 0.65278197, 0.65658402, 0.64240251,
#        0.58214866, 0.49107375, 0.50274769, 0.67140181, 0.6334955 ,
#        0.61086348, 0.3705098 , 0.63898998, 0.5139141 ]), 'split2_test_score': array([0.73209043, 0.68099989, 0.79105039, 0.76372423, 0.69252399,
#        0.66778427, 0.69916681, 0.74882418, 0.66884488, 0.7818938 ,
#        0.76675826, 0.61720939, 0.73039324, 0.79292344, 0.55395851,
#        0.67865076, 0.39783079, 0.70117626, 0.7619347 , 0.7109884 ,
#        0.72965125, 0.72813031, 0.73721397, 0.62291038]), 'split3_test_score': array([0.72827943, 0.63121447, 0.72966827, 0.60156057, 0.58786027,
#        0.65525132, 0.72943986, 0.69242128, 0.66384428, 0.66143934,
#        0.74831925, 0.70561333, 0.74226028, 0.6863822 , 0.69635473,
#        0.71360206, 0.62941742, 0.68084942, 0.71436533, 0.71420471,
#        0.66778581, 0.67893243, 0.72030866, 0.67115989]), 'split4_test_score': array([0.69411039, 0.7147029 , 0.62267141, 0.65217354, 0.67960334,
#        0.65246902, 0.73730689, 0.69496484, 0.56785725, 0.69790301,
#        0.6087792 , 0.64843085, 0.68801085, 0.70615944, 0.61877901,
#        0.68109762, 0.62032872, 0.71024993, 0.69945063, 0.66307407,
#        0.64349297, 0.69620921, 0.72224284, 0.61732466]), 'mean_test_score': array([0.69695815, 0.66073774, 0.68635319, 0.66060545, 0.65424372,
#        0.6289618 , 0.70280364, 0.66944203, 0.62378426, 0.66296663,
#        0.70523343, 0.63434699, 0.709061  , 0.71424167, 0.64607553,
#        0.6600869 , 0.57545332, 0.6606812 , 0.71970717, 0.66708636,
#        0.6758354 , 0.63186037, 0.70898285, 0.62201255]), 'std_test_score': array([0.04908248, 0.0346552 , 0.08584479, 0.06662651, 0.03742515,
#        0.09637469, 0.06176251, 0.06337468, 0.05272657, 0.0900224 ,
#        0.06782171, 0.04189105, 0.03372663, 0.04599833, 0.05843466,
#        0.04461811, 0.11850538, 0.07965186, 0.03334311, 0.0403618 ,
#        0.04665948, 0.13176338, 0.03548271, 0.06009987]), 'rank_test_score': array([ 7, 13,  8, 15, 17, 21,  6, 10, 22, 12,  5, 19,  3,  2, 18, 16, 24,
#        14,  1, 11,  9, 20,  4, 23])}

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.016471      0.001745         0.005719        0.006150
# 1        0.009376      0.007655         0.009376        0.007656
# 2        0.012501      0.006250         0.003125        0.006250
# 3        0.009375      0.007655         0.006251        0.007656
# 4        0.015628      0.000001         0.003126        0.006252
# 5        0.009376      0.007655         0.003125        0.006251
# 6        0.078131      0.000003         0.000000        0.000000
# 7        0.062505      0.009882         0.000000        0.000000
# 8        0.048635      0.003508         0.000000        0.000000
# 9        0.038382      0.007116         0.000872        0.001744
# 10       0.040627      0.007652         0.003125        0.006250
# 11       0.040627      0.007653         0.003125        0.006250
# 12       0.015634      0.000012         0.003125        0.006250
# 13       0.012502      0.006251         0.000000        0.000000
# 14       0.009375      0.007654         0.006252        0.007658
# 15       0.012501      0.006251         0.003125        0.006250
# 16       0.015626      0.000003         0.000000        0.000000
# 17       0.009378      0.007657         0.000000        0.000000
# 18       0.015625      0.000004         0.003126        0.006252
# 19       0.009375      0.007655         0.003126        0.006252
# 20       0.009377      0.007656         0.006252        0.007658
# 21       0.012501      0.006250         0.003125        0.006249
# 22       0.015626      0.000002         0.000000        0.000000
# 23       0.009376      0.007655         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.727602
# 1   {'criterion': 'squared_error', 'max_features':...           0.658526
# 2   {'criterion': 'squared_error', 'max_features':...           0.734736
# 3   {'criterion': 'squared_error', 'max_features':...           0.703486
# 4   {'criterion': 'squared_error', 'max_features':...           0.671175
# 5   {'criterion': 'squared_error', 'max_features':...           0.725654
# 6   {'criterion': 'absolute_error', 'max_features'...           0.762105
# 7   {'criterion': 'absolute_error', 'max_features'...           0.652530
# 8   {'criterion': 'absolute_error', 'max_features'...           0.667115
# 9   {'criterion': 'absolute_error', 'max_features'...           0.669110
# 10  {'criterion': 'absolute_error', 'max_features'...           0.764482
# 11  {'criterion': 'absolute_error', 'max_features'...           0.579302
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.731859
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.729159
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.718883
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.644935
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.738616
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.708383
# 18  {'criterion': 'poisson', 'max_features': None,...           0.751383
# 19  {'criterion': 'poisson', 'max_features': None,...           0.613669
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.727384
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.685520
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.726159
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.684754
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.602709           0.732090           0.728279
# 1            0.618245           0.681000           0.631214
# 2            0.553640           0.791050           0.729668
# 3            0.582083           0.763724           0.601561
# 4            0.640056           0.692524           0.587860
# 5            0.443651           0.667784           0.655251
# 6            0.586000           0.699167           0.729440
# 7            0.558470           0.748824           0.692421
# 8            0.551260           0.668845           0.663844
# 9            0.504487           0.781894           0.661439
# 10           0.637828           0.766758           0.748319
# 11           0.621180           0.617209           0.705613
# 12           0.652782           0.730393           0.742260
# 13           0.656584           0.792923           0.686382
# 14           0.642403           0.553959           0.696355
# 15           0.582149           0.678651           0.713602
# 16           0.491074           0.397831           0.629417
# 17           0.502748           0.701176           0.680849
# 18           0.671402           0.761935           0.714365
# 19           0.633495           0.710988           0.714205
# 20           0.610863           0.729651           0.667786
# 21           0.370510           0.728130           0.678932
# 22           0.638990           0.737214           0.720309
# 23           0.513914           0.622910           0.671160
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.694110         0.696958        0.049082                7
# 1            0.714703         0.660738        0.034655               13
# 2            0.622671         0.686353        0.085845                8
# 3            0.652174         0.660605        0.066627               15
# 4            0.679603         0.654244        0.037425               17
# 5            0.652469         0.628962        0.096375               21
# 6            0.737307         0.702804        0.061763                6
# 7            0.694965         0.669442        0.063375               10
# 8            0.567857         0.623784        0.052727               22
# 9            0.697903         0.662967        0.090022               12
# 10           0.608779         0.705233        0.067822                5
# 11           0.648431         0.634347        0.041891               19
# 12           0.688011         0.709061        0.033727                3
# 13           0.706159         0.714242        0.045998                2
# 14           0.618779         0.646076        0.058435               18
# 15           0.681098         0.660087        0.044618               16
# 16           0.620329         0.575453        0.118505               24
# 17           0.710250         0.660681        0.079652               14
# 18           0.699451         0.719707        0.033343                1
# 19           0.663074         0.667086        0.040362               11
# 20           0.643493         0.675835        0.046659                9
# 21           0.696209         0.631860        0.131763               20
# 22           0.722243         0.708983        0.035483                4
# 23           0.617325         0.622013        0.060100               23

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}

# %%
Y_predict=grid.predict(train_independent)
Y_predict
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
from sklearn.metrics import r2_score
r2=r2_score(dependent,Y_predict)
r2
# Out:
# 0.998667156135576

# %%
import pickle
pickle.dump(grid,open('finalized_DecisionTreeWithoutSplit_model.sav','wb'))

# %%
loaded_model=pickle.load(open('finalized_DecisionTreeWithoutSplit_model.sav','rb'))
preinput=sc.transform([[40,28.5,2,1,0]])
result=loaded_model.predict(preinput)
print(preinput)
print(result)
# Out:
# [[ 0.05646073 -0.35489331  0.75107928  0.98959079 -0.5074631 ]]
# [6600.361]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
